# %%
# Variables - wadah untuk menyimpan data
nama = 'Mirwan'
umur = 29
tinggi = 172
aktif = True

print(nama)
print(umur)
print(tinggi)
print(aktif)
# Out:
# Mirwan
# 29
# 172
# True

# %%
# CEK TIPE DATA dengan type()
nama = 'Mirwan'
umur = 19
tinggi = 172.5
aktif = True

print(type(nama)) #str = teks
print(type(umur)) #int = bilangan bulat
print(type(tinggi)) #float = bilangan desimal
print(type(aktif)) # bool = True/False
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
# OPERASI MATEMATIKA
a = 100
b = 30

print(a + b) #penjumlahan
print(a - b) #pengurangan
print(a * b) #perkalian
print(a / b) #pembagian
print(a // b) #pembagian bulat (buang desimal)
print(a % b) #sisa bagi
print(a ** 2) #pangkat
# Out:
# 130
# 70
# 3000
# 3.3333333333333335
# 3
# 10
# 10000

# %%
# OPERASI PAD TEKS (STRING)
nama_depan = 'Mirwan'
nama_belakang = 'Alkhatiri'

nama lengkap = nama_depan + " " + nama_belakang # gabung teks
print(nama_lengkap)
print(len(nama_lengkap)) #hitung jumlah karakter
print(nama_lengkap.upper()) #huruf besar semua
print(nama_lengkap.lower()) #huruf kecil semua
print(nama_lengkap.replace("Mirwan", "Bro")) #ganti kata
# Out:
#   Cell In[12], line 5
#     nama lengkap = nama_depan + " " + nama_belakang # gabung teks
#          ^
# SyntaxError: invalid syntax
